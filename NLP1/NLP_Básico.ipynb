# %% [markdown]
# ![coderhouse-logo.png](data:image/png;base64,...)

# %% [markdown]
# # Carga de datos
# Utilizamos un conjunto de datos de alrededor de 37000 reseñas de videos de Amazon Instant Video y 1700000 reseñas de películas y programas de televisión, todas obtenidas del sitio web: http://jmcauley.ucsd.edu/data/amazon/. Tenga en cuenta que hay conjuntos de datos mucho más grandes disponibles en el mismo sitio. Podemos esperar resultados mejores y más consistentes en conjuntos de datos más grandes (como reseñas de libros). Tenga en cuenta que estos conjuntos de datos están comprimidos (gzip) y están en formato JSON, cada línea representa una revisión y cada línea es su propio objeto JSON.
#
# Comenzamos cargando el conjunto de datos a continuación:

# %%
# %%time
import gzip
import json
import string

import nltk # imports the natural language toolkit
import pandas as pd
import plotly

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# CPU times: user 2.26 s, sys: 647 ms, total: 2.9 s
# Wall time: 3.62 s
# True

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en dr
import os
print(os.getcwd())
os.chdir("/content/gdrive/My Drive")
# Out:
# Mounted at /content/gdrive
# /content

# %%
os.getcwd()
instant_video = pd.read_json("reviews_Amazon_Instant_Video_5.json.gz", lines=True, compression='gzip')

# %%
type(instant_video)
instant_video.head()
# Out:
#        reviewerID        asin                    reviewerName helpful  \
# 0  A11N155CW1UV02  B000H00VBQ                        AdrianaM  [0, 0]
# 1  A3BC8O2KCL29V2  B000H00VBQ                         Carol T  [0, 0]
# 2   A60D5HQFOTSOM  B000H00VBQ  Daniel Cooper "dancoopermedia"  [0, 1]
# 3  A1RJPIGRSNX4PW  B000H00VBQ                  J. Kaplan "JJ"  [0, 0]
# 4  A16XRPF40679KG  B000H00VBQ                   Michael Dobey  [1, 1]
#
#                                           reviewText  overall  \
# 0  I had big expectations because I love English ...        2
# 1  I highly recommend this series. It is a must f...        5
# 2  This one is a real snoozer. Don't believe anyt...        1
# 3  Mysteries are interesting.  The tension betwee...        4
# 4  This show always is excellent, as far as briti...        5
#
#                           summary  unixReviewTime   reviewTime
# 0      A little bit boring for me      1399075200   05 3, 2014
# 1           Excellent Grown Up TV      1346630400   09 3, 2012
# 2           Way too boring for me      1381881600  10 16, 2013
# 3     Robson Green is mesmerizing      1383091200  10 30, 2013
# 4  Robson green and great writing      1234310400  02 11, 2009

# %% [markdown]
# **Problema de negocio**. Su tarea principal es explorar los datos proporcionados y utilizar los resultados de su investigación para diseñar funciones relevantes que podrían facilitar el análisis posterior y la creación de modelos.

# %%
# %%time
# podemos decirle a pandas que nuestro archivo esta en formato gzip y realizara el proceso de descompresion
# para esto usamos el atributo `lines=True` para indicar que cada linea en el archivo tiene su propio JSON object
#instant_video = pd.read_json("reviews_Amazon_Instant_Video_5.json.gz", lines=True, compression='gzip')
# ----------
# El archivo Películas y TV es muy grande. Si tienes problemas para cargarlo, puedes cargar solo los primeros
# 100,000 reseñas usando 'chunksize' (elimine el comentario de la línea con 'chunksize' y comente la línea
# después de lo que carga el archivo completo en `movies_tv`). Todo el análisis puede ser
# hecho de la misma manera utilizando solo el subconjunto de revisiones, pero algunos de los resultados pueden ser diferentes de los ejemplos.
# ----------
movies_tv = next(pd.read_json("reviews_Movies_and_TV_5.json.gz", lines=True, compression='gzip', chunksize=100000))
#movies_tv = pd.read_json("reviews_Movies_and_TV_5.json.gz", lines=True, compression='gzip')
# Out:
# CPU times: user 3.44 s, sys: 1.18 s, total: 4.62 s
# Wall time: 5.66 s

# %% [markdown]
# Miremos algunos de los atributos
#
# * **reviewerID:** A unique ID to identify the author of the review.
# * **asin:** The ["Amazon Standard Identification Number"](https://www.amazon.com/gp/seller/asin-upc-isbn-info.html) which provides more information about the exact product and version.
# * **reviewerName:** The username chosen by the reviewer.
# * **helpful:** A record of how many users indicated that the review was helpful/not helpful.
# * **reviewText:** The full text of the review.
# * **overall:** The overall rating (1-5) left by the reviewer.
# * **summary:** A short version of the review, used as the title.
# * **unixReviewTime:** The date that the review was created, in [Unix Epoch](https://en.wikipedia.org/wiki/Unix_time) format.
# * **reviewTime:** A human readable date giving the day, month, and year.

# %%
print(len(instant_video))
print(instant_video.head(5))
# Out:
# 37126
#        reviewerID        asin                    reviewerName helpful  \
# 0  A11N155CW1UV02  B000H00VBQ                        AdrianaM  [0, 0]
# 1  A3BC8O2KCL29V2  B000H00VBQ                         Carol T  [0, 0]
# 2   A60D5HQFOTSOM  B000H00VBQ  Daniel Cooper "dancoopermedia"  [0, 1]
# 3  A1RJPIGRSNX4PW  B000H00VBQ                  J. Kaplan "JJ"  [0, 0]
# 4  A16XRPF40679KG  B000H00VBQ                   Michael Dobey  [1, 1]
#
#                                           reviewText  overall  \
# 0  I had big expectations because I love English ...        2
# 1  I highly recommend this series. It is a must f...        5
# 2  This one is a real snoozer. Don't believe anyt...        1
# 3  Mysteries are interesting.  The tension betwee...        4
# 4  This show always is excellent, as far as briti...        5
#
#                           summary  unixReviewTime   reviewTime
# 0      A little bit boring for me      1399075200   05 3, 2014
# 1           Excellent Grown Up TV      1346630400   09 3, 2012
# 2           Way too boring for me      1381881600  10 16, 2013
# 3     Robson Green is mesmerizing      1383091200  10 30, 2013
# 4  Robson green and great writing      1234310400  02 11, 2009

# %%
print(len(movies_tv))
print(movies_tv.head(5))
# Out:
# 100000
#        reviewerID        asin                         reviewerName helpful  \
# 0   ADZPIG9QOCDG5  0005019281  Alice L. Larson "alice-loves-books"  [0, 0]
# 1  A35947ZP82G7JH  0005019281                        Amarah Strack  [0, 0]
# 2  A3UORV8A9D5L2E  0005019281                      Amazon Customer  [0, 0]
# 3  A1VKW06X1O2X7V  0005019281           Amazon Customer "Softmill"  [0, 0]
# 4  A3R27T4HADWFFJ  0005019281                                 BABE  [0, 0]
#
#                                           reviewText  overall  \
# 0  This is a charming version of the classic Dick...        4
# 1  It was good but not as emotionally moving as t...        3
# 2  Don't get me wrong, Winkler is a wonderful cha...        3
# 3  Henry Winkler is very good in this twist on th...        5
# 4  This is one of the best Scrooge movies out.  H...        4
#
#                                         summary  unixReviewTime   reviewTime
# 0                     good version of a classic      1203984000  02 26, 2008
# 1                        Good but not as moving      1388361600  12 30, 2013
# 2         Winkler's Performance was ok at best!      1388361600  12 30, 2013
# 3  It's an enjoyable twist on the classic story      1202860800  02 13, 2008
# 4                              Best Scrooge yet      1387670400  12 22, 2013

# %% [markdown]
# Notamos que `movies_tv` es extremadamente larga con casi 2 millones de reseñas, y varias columnas parecen poco interesantes o difíciles de trabajar (por ejemplo, `reviewerID`, `asin`, `reviewername`, `reviewtime`). Dejamos caer alguna información para hacer que algunos de nuestros análisis posteriores sean más eficientes. También agregamos una columna de fecha y hora con objetos de fecha y hora de Python para resumir más fácilmente los datos:
#
# Comenzamos cargando el conjunto de datos a continuación:

# %%
# %%time
movies_tv['datetime'] = pd.to_datetime(movies_tv['reviewTime'], format="%m %d, %Y")
instant_video['datetime'] = pd.to_datetime(instant_video['reviewTime'], format="%m %d, %Y")
# Out:
# CPU times: user 336 ms, sys: 0 ns, total: 336 ms
# Wall time: 338 ms

# %%
movies_tv = movies_tv.drop(columns = ['reviewerID', 'asin', 'reviewerName', 'reviewTime'])
instant_video = instant_video.drop(columns = ['reviewerID', 'asin', 'reviewerName', 'reviewTime'])

movies_tv.head(5)
# Out:
#   helpful                                         reviewText  overall  \
# 0  [0, 0]  This is a charming version of the classic Dick...        4
# 1  [0, 0]  It was good but not as emotionally moving as t...        3
# 2  [0, 0]  Don't get me wrong, Winkler is a wonderful cha...        3
# 3  [0, 0]  Henry Winkler is very good in this twist on th...        5
# 4  [0, 0]  This is one of the best Scrooge movies out.  H...        4
#
#                                         summary  unixReviewTime   datetime
# 0                     good version of a classic      1203984000 2008-02-26
# 1                        Good but not as moving      1388361600 2013-12-30
# 2         Winkler's Performance was ok at best!      1388361600 2013-12-30
# 3  It's an enjoyable twist on the classic story      1202860800 2008-02-13
# 4                              Best Scrooge yet      1387670400 2013-12-22

# %%
movies_tv.datetime.value_counts().head(20)
# Out:
# 2013-06-05    114
# 2014-01-09    105
# 2014-01-01    104
# 2014-01-04     97
# 2013-04-17     95
# 2014-01-08     95
# 2014-01-07     95
# 2013-12-29     92
# 2014-01-03     90
# 2013-12-05     89
# 2013-04-28     88
# 2013-05-10     88
# 2014-01-14     87
# 2012-12-28     86
# 2014-02-17     86
# 2014-07-08     85
# 2012-12-11     84
# 2014-01-28     84
# 2014-07-07     84
# 2014-02-18     84
# Name: datetime, dtype: int64

# %%
movies_tv.datetime.dt.year.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogramas de conteos

# %%
instant_video.hist()
movies_tv.hist()
# Out:
# array([[<AxesSubplot:title={'center':'overall'}>,
#         <AxesSubplot:title={'center':'unixReviewTime'}>],
#        [<AxesSubplot:title={'center':'datetime'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Notamos eso:
#
# 1. La mayoría de las reseñas son buenas; de hecho, ¡más de la mitad son perfectas (5/5 estrellas) en ambos conjuntos de datos!
# 2. Casi todas las revisiones de videos instantáneos son extremadamente recientes. Será muy difícil detectar tendencias sin corregir esto. Las reseñas de TV Movie están sustancialmente más dispersas (aunque también incluyen un pico reciente).

# %%
instant_video['year'] = instant_video.datetime.dt.year
instant_video.groupby(['year']).agg({'overall': 'mean', 'year': 'count'})
# Out:
#        overall   year
# year
# 2000  5.000000      1
# 2004  4.000000      1
# 2006  4.937500     16
# 2007  4.245763    118
# 2008  4.298701    231
# 2009  4.251381    362
# 2010  4.093085    376
# 2011  4.012414    725
# 2012  4.111845   2727
# 2013  4.251077  16019
# 2014  4.193535  16550

# %%
movies_tv['year'] = movies_tv.datetime.dt.year
movies_tv.groupby(['year']).agg({'overall': 'mean', 'year': 'count'})
# Out:
#        overall   year
# year
# 1997  5.000000      3
# 1998  3.975207    121
# 1999  4.014799   1419
# 2000  4.060704   7726
# 2001  4.112570   5712
# 2002  4.198121   5108
# 2003  4.224021   4879
# 2004  4.143942   6058
# 2005  4.182651   6329
# 2006  4.177677   5268
# 2007  4.285928   5351
# 2008  4.185248   4691
# 2009  4.238243   4189
# 2010  4.214250   3972
# 2011  4.219965   3987
# 2012  4.385321   6758
# 2013  4.493982  18280
# 2014  4.498177  10149

# %% [markdown]
# # Promedio de ratings en el tiempo

# %%
result = instant_video.groupby(instant_video.datetime.dt.year).agg({'overall': 'mean', 'overall': 'count'})
result
# Out:
#           overall
# datetime
# 2000            1
# 2004            1
# 2006           16
# 2007          118
# 2008          231
# 2009          362
# 2010          376
# 2011          725
# 2012         2727
# 2013        16019
# 2014        16550

# %%
instant_video.groupby(instant_video.datetime.dt.year)['overall'].mean().to_frame().plot(kind="bar")
movies_tv.groupby(movies_tv.datetime.dt.year)['overall'].mean().to_frame().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Notamos eso:
#
# 1. No hay tendencias notables de cambio de calificaciones con el tiempo.
#
# 2. Hay algunos años atípicos con calificaciones más altas, pero estos son años en los que la cantidad de revisiones es muy pequeña, lo que hace que el promedio sea menos confiable.

# %% [markdown]
# # Promedios longitudes de revisiones por año

# %%
instant_video['length'] = instant_video['reviewText'].apply(len)
instant_video.groupby(instant_video.datetime.dt.year)['length'].mean().to_frame().plot(kind="bar")

movies_tv['length'] = movies_tv['reviewText'].apply(len)
movies_tv.groupby(movies_tv.datetime.dt.year)['length'].mean().to_frame().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Observamos una aparente tendencia al alza en la duración de las reseñas durante la década de 1990 y principios de la de 2000, seguida de una tendencia a la baja. Debido a que ambos conjuntos de datos tienen revisiones más recientes, la tendencia a la baja en la duración de la revisión es más confiable.

# %% [markdown]
# # Encontrar palabras mas frecuentes

# %% [markdown]
# Encontremos las diez palabras sin stopwrods que aparecen con mayor frecuencia en: (i) todas las reseñas, (ii) reseñas positivas, (iii) reseñas negativas. ¿Te sorprenden los resultados? ¿Por qué o por qué no?

# %%
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime

short_movies_tv = movies_tv.head(100000)

def get_top_n_words(corpus, n=1, k=1):
    t1 = datetime.now()
    vec = CountVectorizer(ngram_range=(k, k), stop_words="english")
    bag_of_words = vec.fit_transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
vec = CountVectorizer(ngram_range=(1, 1), stop_words="english")
bag_of_words = vec.fit_transform(short_movies_tv["reviewText"])

# %%
 bag_of_words.sum(axis=0)
# Out:
# matrix([[315, 905,   1, ...,   2,   1,   1]])

# %%
# %%time
# Todos los reviews
common_words = get_top_n_words(short_movies_tv["reviewText"], 20, 1)
for word, freq in common_words:
    print(word, freq)

df = pd.DataFrame(common_words, columns=["words", "count"])
df.groupby("words").sum()["count"].sort_values(ascending=False).plot(
    kind="bar", title="Top 20 words from all reviews"
)
# Out:
# movie 146139
# film 117896
# like 49747
# great 46391
# good 44771
# quot 44715
# just 43336
# time 39939
# story 35359
# really 29202
# dvd 28395
# best 27908
# movies 25999
# love 25779
# watch 22436
# people 21950
# way 21529
# don 21374
# life 20965
# films 20363
# CPU times: user 16.5 s, sys: 157 ms, total: 16.6 s
# Wall time: 16.7 s
# <AxesSubplot:title={'center':'Top 20 words from all reviews'}, xlabel='words'>

# %%
# %%time
# reviews Positivos
good_indices = short_movies_tv["overall"] > 3.1
good_reviews = short_movies_tv[good_indices]
bad_indices = short_movies_tv["overall"] < 2.1
bad_reviews = short_movies_tv[bad_indices]

common_words = get_top_n_words(good_reviews["reviewText"], 20)
for word, freq in common_words:
    print(word, freq)

df = pd.DataFrame(common_words, columns=["words", 'count'])
df.groupby('words').sum()['count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 20 words from good reviews'
)
# Out:
# movie 115580
# film 93835
# great 41013
# like 37190
# quot 34366
# good 34320
# time 32859
# just 31716
# story 28559
# best 24257
# dvd 23076
# love 22405
# really 22185
# movies 21329
# watch 18387
# life 17972
# people 17203
# way 16891
# films 16620
# don 15604
# CPU times: user 13.2 s, sys: 119 ms, total: 13.4 s
# Wall time: 13.4 s
# <AxesSubplot:title={'center':'Top 20 words from good reviews'}, xlabel='words'>

# %%
# %%time
# reviews Negativos
common_words = get_top_n_words(bad_reviews['reviewText'], 20)
for word, freq in common_words:
    print(word, freq)
df = pd.DataFrame(common_words, columns=['words', 'count'])
df.groupby('words').sum()['count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 20 words from bad reviews'
)
# Out:
# movie 16098
# film 10802
# like 6400
# just 6185
# quot 5348
# good 4302
# time 3401
# really 3311
# don 3164
# story 3005
# bad 2919
# people 2603
# dvd 2572
# make 2366
# movies 2350
# better 2255
# did 2202
# way 2198
# great 2185
# character 2158
# CPU times: user 1.74 s, sys: 49.6 ms, total: 1.79 s
# Wall time: 1.75 s
# <AxesSubplot:title={'center':'Top 20 words from bad reviews'}, xlabel='words'>

# %% [markdown]
# Tengan en cuenta que los resultados son casi idénticos en los tres grupos de reseñas: casi todas las palabras más importantes son palabras genéricas muy comunes sobre películas (es decir, "película" en sí). Como vimos en el caso anterior, esto no es tan sorprendente, dado que estamos tratando con datos en un contexto específico de una película, y las palabras vacías solo tendrán en cuenta las palabras genéricas que aparecen en muchos contextos en inglés, las stopwords más comunes serán el vocabulario básico relacionado con las películas, no necesariamente palabras más precisas que den más color a las reseñas en sí.

# %% [markdown]
# Encuentremos las palabras que sean indicativas de malas críticas. Es decir, palabras que aparecen a menudo en malas críticas y no en buenas críticas. ¿Qué son estas palabras y son sorprendentes?

# %%
# %%time
from collections import Counter

def get_indicative_words(text1, text2, n=20):
    c1 = Counter(text1.lower().split(" "))
    c2 = Counter(text2.lower().split(" "))
    ind_words_1 = (c1 - c2).most_common(n)
    ind_words_2 = (c2 - c1).most_common(n)
    x, y = zip(*ind_words_2)

    df = pd.DataFrame({'word': x, 'count': y})
    df.plot.barh(
        x='word', y='count', figsize=(10,10)
    )

get_indicative_words(' '.join(good_reviews['reviewText']), ' '.join(bad_reviews['reviewText']))
# Out:
# CPU times: user 6.6 s, sys: 1.23 s, total: 7.83 s
# Wall time: 7.86 s

# %%
text1 = ' '.join(good_reviews['reviewText'])
text2 = ' '.join(bad_reviews['reviewText'])

# %%
c1 = Counter(text1.lower().split(" "))
c2 = Counter(text2.lower().split(" "))
ind_words_1 = (c1 - c2).most_common(20)
ind_words_2 = (c2 - c1).most_common(20)

# %%
c1 - c2
# Out:
# Counter({'this': 149357,
#          'is': 242856,
#          'a': 316991,
#          'charming': 725,
#          'version': 7598,
#          'of': 308426,
#          'the': 672144,
#          'classic': 8060,
#          "dicken's": 15,
#          'tale.': 238,
#          '': 227375,
#          'henry': 1077,
#          'winkler': 61,
#          'makes': 9330,
#          'good': 24084,
#          'showing': 1328,
#          'as': 99107,
#          '"scrooge"': 3,
#          'character.': 929,
#          'even': 16817,
#          'though': 5989,
#          'you': 64605,
#          'know': 9250,
#          'what': 25210,
#          'will': 25325,
#          'happen': 1235,
#          'has': 38051,
#          'enough': 3923,
#          'change': 1534,
#          'to': 250549,
#          'make': 11649,
#          'it': 127350,
#          'better': 7580,
#          'that': 123675,
#          'average.': 31,
#          'if': 25570,
#          'love': 18195,
#          'christmas': 2134,
#          'carol': 274,
#          'in': 183914,
#          'any': 10869,
#          'version,': 868,
#          'then': 11051,
#          'this.': 1407,
#          'very': 28430,
#          'twist': 629,
#          'on': 67449,
#          'story.': 2492,
#          'not': 47509,
#          'conventional': 185,
#          'remake,': 69,
#          'but': 67658,
#          'story': 18645,
#          'set': 5697,
#          'early': 2997,
#          'america.': 297,
#          'give': 5227,
#          'try.': 121,
#          'one': 53175,
#          'best': 19605,
#          'scrooge': 160,
#          'movies': 13028,
#          'out.': 1807,
#          'outdoes': 25,
#          'himself.': 603,
#          'casting': 811,
#          'excellent': 6459,
#          'and': 354873,
#          'music': 5289,
#          'theme': 1411,
#          'old': 8260,
#          'relevant.': 37,
#          'been': 15446,
#          'favorite': 6606,
#          'movie': 68896,
#          'mine': 426,
#          'for': 90451,
#          'long': 5452,
#          'time.': 4759,
#          'great': 33827,
#          'modern': 2104,
#          'day': 3930,
#          'scrooge.': 42,
#          'there': 22285,
#          'are': 58507,
#          'many': 15918,
#          'giving': 1439,
#          'new': 10746,
#          'dickens,': 7,
#          'true': 5559,
#          'original': 7084,
#          'during': 4814,
#          'depression.': 50,
#          'american': 4636,
#          'adaptation': 1007,
#          'charles': 763,
#          "dickens'": 71,
#          'classic.': 1684,
#          'interesting': 3935,
#          'main': 2671,
#          'character': 8388,
#          'seen': 11699,
#          'ripping': 49,
#          'pages': 172,
#          'out': 24557,
#          "collector's": 503,
#          'item': 225,
#          'book': 4333,
#          '"a': 620,
#          'carol."henry': 1,
#          'gives': 4236,
#          'an': 43627,
#          'outstanding': 1501,
#          'performance': 5669,
#          'benedict': 48,
#          'slade,': 29,
#          'loan': 71,
#          'officer': 500,
#          'who': 41751,
#          'reclaims': 6,
#          'valued': 25,
#          'possessions': 30,
#          'those': 10604,
#          'unable': 411,
#          'late': 1953,
#          'payments': 5,
#          'eve.his': 1,
#          'visit': 489,
#          'by': 48392,
#          'spirits,': 20,
#          'life': 10151,
#          'orphanage': 66,
#          'how': 16110,
#          'man': 9000,
#          'helped': 709,
#          'him,': 1708,
#          'leads': 1162,
#          'sentimental': 166,
#          'would': 17796,
#          'have': 47363,
#          'images': 867,
#          'could': 10097,
#          'be': 42807,
#          'enhanced': 365,
#          'viewing.': 429,
#          'originally': 883,
#          'was': 73174,
#          'program': 431,
#          'presented': 1094,
#          'complete': 1392,
#          'with': 88837,
#          'fade-outs': 1,
#          'commercial': 269,
#          'breaks.david': 1,
#          'wayne': 1151,
#          'owner': 412,
#          'well': 15298,
#          'christmases': 6,
#          'past.': 307,
#          'glad': 1640,
#          'came': 4469,
#          'dvd.': 2184,
#          'i': 123113,
#          'waiting': 817,
#          "haven't": 2077,
#          'production': 2299,
#          'since': 5834,
#          'years': 9143,
#          'ago.': 709,
#          'plus': 1102,
#          "it's": 29348,
#          'than': 17745,
#          'some': 24690,
#          'hallmark': 62,
#          'holiday': 484,
#          'movies.': 2748,
#          'dhenry': 1,
#          'does': 11090,
#          'job.a': 4,
#          'film': 56697,
#          'recommend': 5081,
#          'all': 41658,
#          'ages.': 286,
#          'bitter': 240,
#          'comes': 5042,
#          'meaning': 753,
#          'christmas.': 215,
#          'realizing': 228,
#          'his': 69700,
#          'lost': 2376,
#          'life.': 2360,
#          'small': 3166,
#          'historic': 164,
#          'canadian': 127,
#          'town': 2724,
#          'elora,': 1,
#          'its': 17144,
#          'century-old': 4,
#          'buildings,': 32,
#          'perfect': 4620,
#          'setting': 891,
#          'story,': 2747,
#          "1900's.": 18,
#          'bringing': 684,
#          '20th': 404,
#          'century': 638,
#          'america': 728,
#          'allows': 691,
#          'incorporate': 43,
#          'situations': 444,
#          'americans': 399,
#          'can': 22375,
#          'more': 25399,
#          'easily': 1601,
#          'with.': 496,
#          'job': 4938,
#          'recreating': 35,
#          'character,': 1163,
#          'supporting': 2252,
#          'cast': 6997,
#          'no': 15112,
#          'less': 2460,
#          'admirable.': 8,
#          'annual': 93,
#          '&#34;must': 14,
#          'watch&#34;': 3,
#          'me.': 1511,
#          "don't": 10826,
#          'care': 1406,
#          'winklers': 3,
#          'acting': 6136,
#          'liked': 2953,
#          'fit': 832,
#          'him': 13802,
#          'real': 7606,
#          'thanksdale': 1,
#          'first': 17626,
#          'time': 17861,
#          'saw': 6350,
#          '&#34;an': 3,
#          'carol&#34;': 6,
#          'immediately': 676,
#          'fell': 486,
#          'it.': 12098,
#          "didn't": 4525,
#          'grow': 625,
#          'up': 20326,
#          'depression': 160,
#          'my': 28791,
#          'father': 2584,
#          'did': 8863,
#          'he': 58750,
#          'told': 1650,
#          'stories': 1619,
#          'made': 10743,
#          're-imagination': 1,
#          'americanized': 9,
#          'wonderful.': 433,
#          'acting,': 1333,
#          'directing,': 221,
#          'camera': 1466,
#          'work,': 752,
#          'costumes,': 192,
#          'sets,': 255,
#          'locations,': 72,
#          'music,': 1000,
#          'values': 397,
#          'great.': 1805,
#          'always': 8137,
#          'enjoyed': 3979,
#          'actor,': 451,
#          'think': 11095,
#          'far': 4141,
#          'career': 1222,
#          'date.': 263,
#          'highly': 4384,
#          'whole': 4131,
#          'family.ca': 1,
#          'luster': 45,
#          'usa': 173,
#          'about': 28676,
#          'update': 110,
#          'familiar': 965,
#          'redemption.': 126,
#          'rest.': 109,
#          'role.': 929,
#          'really': 18294,
#          'enjoy': 5026,
#          '&#34;christmas': 3,
#          'carol-scrooge&#34;': 1,
#          'own': 8437,
#          'ones': 1120,
#          'watch': 13374,
#          'them': 9981,
#          'each': 6052,
#          'year.': 493,
#          'want': 6364,
#          'add': 2139,
#          'collection': 2086,
#          'different': 4661,
#          'take': 6273,
#          'traditional': 401,
#          'ones.': 215,
#          'wonderful': 5789,
#          'movie.': 13766,
#          'stay': 1087,
#          'faithful': 459,
#          'carol,': 31,
#          'american.': 38,
#          'fun': 5400,
#          'all.': 1324,
#          'anorher': 1,
#          'watchers..a': 1,
#          'little': 10969,
#          'from': 39601,
#          'ordinary': 445,
#          'enjoyable.': 398,
#          "couldn't": 1247,
#          'like': 28371,
#          'fons.': 1,
#          'played': 5629,
#          'part': 6472,
#          'gave': 1678,
#          'yet': 4699,
#          'another': 6609,
#          'carols': 3,
#          'ignore': 229,
#          'negative': 528,
#          'reviews': 1377,
#          'here.': 1376,
#          'tv': 2870,
#          'touches': 456,
#          'me': 11536,
#          'every': 8980,
#          'it;': 172,
#          'which': 20080,
#          'christmas.the': 3,
#          'splendid': 236,
#          'written.': 136,
#          'suitable': 183,
#          'entire': 2734,
#          'family': 5615,
#          'picture': 4477,
#          'era': 844,
#          'our': 6700,
#          'country.': 216,
#          'seems': 4556,
#          'just': 24719,
#          'everybody': 584,
#          'far!': 20,
#          'realistic': 1155,
#          'others': 2403,
#          'period': 1187,
#          'perfect.': 677,
#          'also': 19464,
#          "i've": 5526,
#          'seen;': 10,
#          'opinion.': 343,
#          'must': 8057,
#          'confess': 103,
#          'being': 10729,
#          'bit': 5402,
#          'coinsure': 1,
#          'versions': 1268,
#          'seeing': 3657,
#          'various': 1254,
#          'interpretations': 79,
#          'offered.': 11,
#          'one,': 1342,
#          'however,': 4429,
#          'continues': 631,
#          'favorites.': 420,
#          'forces': 627,
#          'explain': 539,
#          'elements': 1232,
#          'most': 18078,
#          'films': 10473,
#          'overlook': 244,
#          'because': 13605,
#          'they': 32794,
#          'assume': 222,
#          "you're": 2989,
#          'already': 2453,
#          'examples': 192,
#          'include': 1325,
#          '(slade': 1,
#          'film)': 165,
#          'so': 31562,
#          'mean': 1255,
#          'himself': 3435,
#          'man,': 1285,
#          'reason': 1955,
#          'ghost': 480,
#          'dead': 1881,
#          'partner': 399,
#          'miserable': 92,
#          '(not': 510,
#          'understanding': 629,
#          'need': 3332,
#          'do': 12271,
#          'until': 3732,
#          'power).': 2,
#          'performances': 3694,
#          'et': 161,
#          'al': 589,
#          "you've": 1558,
#          'got': 5574,
#          'absolutely': 2435,
#          'film.in': 44,
#          'opinion,': 733,
#          'closer': 477,
#          'spirit': 867,
#          'work': 5439,
#          'derivative': 22,
#          'versions.': 162,
#          'material': 938,
#          'handled': 240,
#          'reverence': 18,
#          'respect': 745,
#          'shows,': 128,
#          'settings': 204,
#          'characters': 7063,
#          'conceived,': 12,
#          'look': 6702,
#          'period.': 271,
#          'piece': 1470,
#          'worth': 6008,
#          'money.': 387,
#          'twist.': 106,
#          'nice': 3311,
#          'capturing': 274,
#          'consequences': 210,
#          'history': 2690,
#          "one's": 578,
#          'personal': 1894,
#          'role': 5226,
#          'provides': 1040,
#          'sobering': 44,
#          'view': 1705,
#          "character's": 391,
#          'choices,': 50,
#          'original,': 453,
#          '&#34;a': 46,
#          'carol,&#34;': 1,
#          'shows': 4341,
#          "man's": 731,
#          'choices': 316,
#          'affect': 191,
#          'around': 5103,
#          'him.': 2587,
#          'anyone': 4014,
#          'collects': 31,
#          'of,': 308,
#          'carol.&#34;': 3,
#          "can't": 5259,
#          'believe': 3438,
#          'took': 2113,
#          '&#34;them&#34;': 2,
#          'get': 16740,
#          'show': 4899,
#          '(1930s': 1,
#          'america)': 5,
#          'hate': 1054,
#          'much': 15150,
#          'alister': 3,
#          'sim': 28,
#          'portrayal': 1362,
#          '1951': 73,
#          'production.': 288,
#          'certainly': 2650,
#          'your': 12072,
#          'visual': 1556,
#          'library.': 381,
#          'fine': 2616,
#          'actor': 2908,
#          'famous': 1649,
#          'proof': 199,
#          'positive.': 27,
#          'ebeneezer': 6,
#          'course,': 2247,
#          'same': 6607,
#          'other': 15151,
#          'versions,': 130,
#          'remake': 725,
#          'brings': 2139,
#          'interpretation': 299,
#          'actors': 5195,
#          'writers.': 26,
#          'easy': 1598,
#          'watch.': 1538,
#          'film.': 10103,
#          'brilliant': 2719,
#          "dickson's": 3,
#          'england.': 128,
#          'written': 1946,
#          'acted,': 221,
#          'shines': 493,
#          'young': 7276,
#          'entrepreneur': 12,
#          'interested': 1088,
#          'wealth': 200,
#          'progress': 106,
#          'romance': 930,
#          'family,': 667,
#          'until...': 3,
#          'away.': 583,
#          'trust': 495,
#          "you'll": 3278,
#          'winkler.': 5,
#          'ago': 1281,
#          "it'll": 188,
#          'favorite.': 289,
#          'stars': 3294,
#          'tale': 1810,
#          'post-depression': 1,
#          'oneof': 8,
#          'ever': 10626,
#          'seen.': 1128,
#          'equally': 823,
#          'at': 37897,
#          'ease': 115,
#          'girlfriend': 605,
#          'or': 24616,
#          'attitude.': 80,
#          'delighted': 127,
#          'discover': 750,
#          'it!': 1659,
#          'title': 1499,
#          'says': 1686,
#          '-': 15849,
#          're-done.': 2,
#          'henery': 1,
#          'play': 3799,
#          'timeless': 703,
#          'investment': 66,
#          'collector': 140,
#          'stories.': 242,
#          'amazing': 3225,
#          'tale,': 214,
#          'awesome': 1710,
#          'sitting': 480,
#          'down': 5661,
#          'cold': 785,
#          'night.': 462,
#          'updated': 139,
#          "doesn't": 5686,
#          'lose': 584,
#          'important': 2001,
#          'stuff.': 327,
#          'family.': 911,
#          'us': 6949,
#          'remember': 3107,
#          'arthur': 499,
#          '"the': 5802,
#          'fonz"': 2,
#          'fonzarelli': 1,
#          'happy': 2280,
#          'days.': 423,
#          'chance': 1371,
#          "he's": 5045,
#          'remember.': 137,
#          "henry's": 55,
#          'reposesses': 1,
#          'furniture': 24,
#          'rented': 275,
#          'poor': 703,
#          'families.': 60,
#          'instead': 1605,
#          'ghosts,': 45,
#          'visions': 174,
#          'involving': 653,
#          'people': 11990,
#          'left': 2557,
#          'destitute.': 3,
#          'sappy': 74,
#          'renditions': 28,
#          'are.': 345,
#          'favorably': 18,
#          'impressed': 653,
#          'acting.': 671,
#          'gerard': 74,
#          'parks': 23,
#          '(doc': 5,
#          'fraggle': 7,
#          'rock)': 19,
#          'it,': 5809,
#          'dorian': 24,
#          'harewood.': 2,
#          'addition': 1041,
#          'collection.': 1626,
#          'excellent.': 865,
#          'only': 17633,
#          'thing': 4187,
#          'say': 7347,
#          'is,': 2505,
#          'too': 7613,
#          'spent': 508,
#          'bored': 168,
#          'otherwise,': 135,
#          'when': 29042,
#          'aired': 198,
#          '1979,': 17,
#          'clean': 626,
#          'forgot': 230,
#          '&quot;a': 191,
#          'carol&quot;.': 2,
#          'wanted': 2307,
#          'see': 19062,
#          'over': 12355,
#          'again': 4303,
#          'thoughout': 6,
#          'finally': 3027,
#          'copy': 1422,
#          'vhs,': 220,
#          'wish.': 42,
#          'now': 7533,
#          'dvd': 14502,
#          'am': 4877,
#          'glad.': 8,
#          'variation': 57,
#          'alistair': 42,
#          'treat': 661,
#          'gods.': 12,
#          'although': 4067,
#          'both': 8821,
#          '1984': 231,
#          '1999': 212,
#          'television': 1074,
#          'george': 1970,
#          'scott': 926,
#          'patrick': 779,
#          'stewart': 790,
#          'dvd,': 1453,
#          'attempt': 815,
#          'bring': 1871,
#          'dickens': 111,
#          'screen.': 1032,
#          'enjoyable': 1402,
#          'today': 1278,
#          '20': 900,
#          'ago,': 682,
#          'way': 10708,
#          'live': 2679,
#          'forever.': 301,
#          'disc': 2604,
#          'before': 7325,
#          'gets': 5445,
#          'over-the-top': 295,
#          'leave': 1763,
#          'somewhat': 1647,
#          'desired': 82,
#          'all-in-all': 12,
#          'rendition': 223,
#          'delightfull': 4,
#          'variant': 18,
#          'treasure': 274,
#          'own.': 714,
#          '(in': 895,
#          'blu': 1697,
#          'ray': 2346,
#          'yes!)': 3,
#          'welcome': 305,
#          'see.': 873,
#          'experienced': 423,
#          'lot': 6475,
#          'might': 3880,
#          'taken': 2009,
#          'place': 3333,
#          'england': 424,
#          'dickens.': 6,
#          'mr': 250,
#          'pertrayal': 1,
#          'error': 93,
#          'ebineser.': 1,
#          'promising,': 5,
#          'driven': 445,
#          'unmoraled': 1,
#          'business': 921,
#          'kind': 3652,
#          'hearted': 141,
#          'senior': 156,
#          'citizen': 222,
#          'quite': 6486,
#          'well.': 3250,
#          'big': 5100,
#          'holywood': 7,
#          'good.': 2106,
#          'loved': 5074,
#          'had': 17177,
#          'vhs': 1680,
#          'player': 694,
#          'player.previously': 1,
#          'bootlegged': 1,
#          'copies': 261,
#          'were': 14719,
#          'available.': 175,
#          'find': 8183,
#          'recently': 1087,
#          'produced': 820,
#          'dvd/bluray.it': 1,
#          'type': 1558,
#          'truly': 4360,
#          'days': 1672,
#          'show.': 599,
#          'kid.': 267,
#          'tailored': 18,
#          'after': 13160,
#          '&#8220;christmas': 1,
#          'carol&#8221;,': 1,
#          'distinct': 175,
#          'differences': 341,
#          'actually': 5071,
#          'stand': 1398,
#          'merit.': 17,
#          'regular': 544,
#          'refreshingly': 49,
#          'superb': 1893,
#          '&#34;scrooge&#34;.': 1,
#          'person': 2122,
#          'needed': 746,
#          'replaced.': 11,
#          'keep': 3520,
#          'thank': 866,
#          'promptness': 4,
#          'receiving': 121,
#          'trying': 3270,
#          'relevant': 272,
#          'again,': 1595,
#          'dresses': 91,
#          'hard': 3600,
#          'times': 5198,
#          'values.': 68,
#          'pleasure': 518,
#          'know,': 586,
#          'speak': 592,
#          'post-2007': 1,
#          'american,': 36,
#          'though.': 543,
#          'watched': 4895,
#          'back': 9633,
#          'when,': 93,
#          'looked': 1206,
#          'since.': 209,
#          'shocked': 266,
#          'here': 4954,
#          'this,': 1689,
#          'great!!': 29,
#          'wife': 2929,
#          'grew': 770,
#          'hampshire': 15,
#          'where': 10826,
#          'takes': 5124,
#          'place;': 11,
#          'we': 18843,
#          'relate': 642,
#          'setting.': 122,
#          'asside': 1,
#          'places': 503,
#          'comfortable': 234,
#          'general;': 4,
#          'versus': 266,
#          'england.both': 1,
#          'spins': 47,
#          'great,': 1444,
#          'adds': 1207,
#          'powerful': 2230,
#          'message.': 183,
#          'carol!': 1,
#          'shown': 1303,
#          'last': 5415,
#          'few': 7155,
#          'years,': 1162,
#          'should': 7447,
#          'be.': 965,
#          'protrays': 12,
#          '&#34;mr.': 6,
#          'scrooge.&#34;': 1,
#          'enjoy!': 322,
#          'high': 3925,
#          'school;': 9,
#          'experience,': 254,
#          'found': 3912,
#          'annoying': 264,
#          'problem': 1066,
#          'continuity:': 2,
#          "winkler's": 6,
#          'growing': 831,
#          '1890s,': 3,
#          'fine,': 171,
#          'point': 2931,
#          'wwi': 71,
#          'war': 4191,
#          'bond': 457,
#          'rally,': 3,
#          'early-thirties.': 1,
#          'fifteen': 131,
#          'later,': 832,
#          'depression,': 60,
#          'man.': 710,
#          "what's": 990,
#          'deal?': 1,
#          "film's": 2383,
#          'producers': 275,
#          'happened': 1135,
#          'wwi-era': 2,
#          'cars': 278,
#          'costumes': 450,
#          'posters': 74,
#          'hanging': 330,
#          'around,': 351,
#          'decided': 1017,
#          'props.': 16,
#          'sense': 2801,
#          'boy': 1860,
#          'early-industrial': 1,
#          'revolution,': 49,
#          'wwi,': 22,
#          'odd.i': 1,
#          "hadn't": 456,
#          'banners': 6,
#          'available,': 92,
#          'cut': 2313,
#          'rally': 37,
#          'kept': 1056,
#          'continuity': 67,
#          'intact.': 45,
#          'slade': 86,
#          'sees': 1316,
#          'gravestone,': 1,
#          'appears': 1148,
#          'born': 871,
#          '1876-': 1,
#          'forty': 129,
#          'scene,': 1086,
#          'mid-fifties': 1,
#          '1933,': 30,
#          'supposed': 620,
#          'taking': 1689,
#          'place.': 508,
#          'maybe': 2001,
#          "i'm": 5909,
#          'teacher,': 106,
#          'bugged': 16,
#          'everyone': 3767,
#          'excited': 242,
#          'spanish': 498,
#          '1898-': 1,
#          'sense,': 278,
#          'save': 1276,
#          'scenes': 8303,
#          'later.': 355,
#          'placed': 363,
#          'scene': 8100,
#          'end': 5459,
#          'civil': 395,
#          '(that': 206,
#          'allowed': 497,
#          'props,)': 1,
#          'making': 4714,
#          'age': 1713,
#          '1933': 130,
#          'believable.': 310,
#          'oh': 541,
#          'well,': 2660,
#          'favorites...': 3,
#          'site.': 26,
#          'plays': 6135,
#          'movie,': 8997,
#          'life!': 76,
#          'scrooge!': 4,
#          'miss': 1879,
#          'seen!': 87,
#          'breath': 290,
#          'fresh': 583,
#          'air.': 109,
#          'never': 12832,
#          'coincidental': 9,
#          'program,': 101,
#          'abc': 45,
#          '30': 644,
#          '2009,': 16,
#          'experiencing': 123,
#          'economic': 111,
#          'malaise': 3,
#          'own!': 57,
#          'having': 4114,
#          'viewing': 1480,
#          'realize': 1327,
#          "i'd": 1514,
#          'forgotten': 506,
#          'downright': 184,
#          'cold-hearted': 27,
#          'is!!!': 5,
#          'politically-correct': 8,
#          '21st': 104,
#          'insulated': 7,
#          'harsh': 313,
#          'emotions': 707,
#          'such': 8230,
#          'portrayed': 1069,
#          'mr.': 2268,
#          "70's": 416,
#          'done': 4382,
#          'actresses': 451,
#          'unpolished': 9,
#          'genuine-ness': 1,
#          'their': 23536,
#          'parts.': 225,
#          'fan': 3774,
#          'carol"': 11,
#          'pleased': 452,
#          'alongside': 213,
#          'ibm': 20,
#          "dickens's": 13,
#          'classic.enjoyed': 1,
#          'video': 3094,
#          'buying.it': 1,
#          'carol&#34;.': 1,
#          'proves': 679,
#          'ability': 990,
#          'forget': 1469,
#          "'the": 601,
#          "fonz'": 1,
#          'amazed': 364,
#          'transformation': 273,
#          'guy': 2807,
#          'guy.': 258,
#          'general': 894,
#          'feel': 5151,
#          'though,': 1075,
#          'grey.': 23,
#          "that's": 4191,
#          'describe': 507,
#          'then,': 853,
#          'bleak': 206,
#          'grey': 218,
#          'history,': 548,
#          'wrote': 831,
#          'book,': 971,
#          "england's": 25,
#          'subdued': 87,
#          'feeling': 1521,
#          'while': 10140,
#          'watching': 6944,
#          "'modern'": 5,
#          'fits': 481,
#          'story.a': 13,
#          '(sorry,': 28,
#          'oliver!)': 1,
#          'classic.by': 1,
#          'way,': 1500,
#          'money,': 426,
#          'finest': 1050,
#          'c.': 535,
#          'followed': 639,
#          'closely': 303,
#          'sim.': 4,
#          'husband': 1340,
#          'prefers': 59,
#          'waited': 200,
#          'come': 5523,
#          'out,': 1440,
#          'bought': 2429,
#          'blue': 749,
#          'quality': 4071,
#          'complaints': 195,
#          'buy': 3861,
#          'amazon.': 185,
#          'opinion': 762,
#          'hope': 1985,
#          'enjoys': 434,
#          'do.': 737,
#          'fav': 63,
#          'versions....set': 1,
#          'unique': 1423,
#          'regarding': 384,
#          "scrooge's": 27,
#          'upbringing': 27,
#          '(when': 119,
#          'repossess': 4,
#          "orphanage's": 2,
#          'piano': 278,
#          'eve!)': 1,
#          'year,': 335,
#          'scott....good': 1,
#          'contrast': 533,
#          'treats.': 4,
#          'possible': 932,
#          'view.': 186,
#          "we've": 406,
#          'anyone.': 234,
#          'grandchildren': 120,
#          'whose': 2126,
#          'interest': 1092,
#          'length.': 80,
#          "'collect'": 1,
#          "'a": 42,
#          "carol',": 1,
#          'one.': 2171,
#          'putting': 551,
#          ...})

# %%
ind_words_1
# Out:
# [('the', 672144),
#  ('and', 354873),
#  ('a', 316991),
#  ('of', 308426),
#  ('to', 250549),
#  ('is', 242856),
#  ('', 227375),
#  ('in', 183914),
#  ('this', 149357),
#  ('it', 127350),
#  ('that', 123675),
#  ('i', 123113),
#  ('as', 99107),
#  ('for', 90451),
#  ('with', 88837),
#  ('was', 73174),
#  ('his', 69700),
#  ('movie', 68896),
#  ('but', 67658),
#  ('on', 67449)]

# %% [markdown]
# Notamos que muchas de las palabras son obviamente indicativas de una mala película, como "horrible", "decepción", "horrible". "Canjeable" es una palabra interesante que no tiene una asociación negativa obvia, pero probablemente indica que incluso en las críticas negativas, los revisores tienden a hablar de "una característica de redimir algo" (o afirman que la película). También hay algo de ruido en los datos, como es normal en los datos de texto. "g" y "shao" no parecen palabras significativas.

# %% [markdown]
# Inspeccionemos manualmente las primeras 10 reseñas negativas que contengan la palabra "buena". ¿Que notaste? ¿Cómo sugiere esto que debemos proceder a continuación?

# %% [markdown]
# Una posible solución se da a continuación. Tenga en cuenta que el uso de códigos de escape Ansi para colorear es un "buen extra" y no se espera necesariamente de las soluciones de los estudiantes:

# %%
v_bad_indices = movies_tv['overall'] < 1.1
v_bad_reviews = movies_tv[v_bad_indices]

RED_START = "\033[91m"
END = "\033[0m"

good_word_bad_review = [rev for rev in v_bad_reviews['reviewText'] if 'good' in rev.lower()]

print(len(good_word_bad_review))
for rev in good_word_bad_review[:1000]:
    good_i = rev.lower().index("good")

    # adicionamos los codigos Ansi para hacer un highlight a los matches
    print(rev[good_i-50: good_i] + RED_START + rev[good_i:good_i+4] + END + rev[good_i+4:good_i +50])
# Out:
# 1266
# good, the story was correct, but naked backsides w
# good but the scene with Yukon discovering peppermi
# th absolutely NO edits whatsoever to the material.Good for us!Edits are for losers!I have spoken.
# t least made it about an interesting story with a good plot and character development...i agree with
# t everything I've seen thus far does not resemble good cinema in any shape, form, or manner. So, I g
# itself is beautifully filmed. The acting is quite good and as a history freak I found it interesting
# rtaining) and provides nothing that makes us feel good or is uplifting or is of any benefit, except
# aterial is tired and lame.  There is only so much good actors can do when the script is chop blockin
# feel guilty...etc..THE HD DVD:If the movie is NOT good, who cares how good the picture is?? Having s
#  as the movie progressed.  There  are a couple of good shots, but they are buried among a heap of co
# good.....except this one.I watched this DVD with a
# connected  they are, what hubris.Lastly, I have a good home theater system and  the sound on the DVD
# rne, who despite  the script, was actually rather good.)  The plot is way too stupid to base  a movi
# d to believe that theology is gum wraper?The only good scene in the movie is three seconds long: Sat
#  on the much-hyped soundtrack to the movie.  It's good-- at least it's above average. But aside from
# over the hill action hero, bad script, no action, good trailer and  marketing= every bad HOLLYWOOD m
# nglish? His voice needs to be dubbed  like in the good old days. The end was the only enjoyable part
# d. By the end of this movie you don't care if the good guy's win, or die.
# want to know is whether the Blu-ray transfers are good and enhance these films or stay with what we
# ng them but if you do, I hope they look very very good.  $144, man......
# good idea; right?  One of the most beloved horror
# man bates at all. Nobody can play Norman Bates as good as Anthony Perkins. The whole movie was like
# sion will know what scene I refer to.Ok.......The good?...........I'm thinking............Still thin
# the guy who plays the rancher with 400 grand is a good take on the character.
# said "so no one else would have to."That is not a good enough reason.While remaking one of the great
#  (I'm not kidding) as the original. Anne Heche is good in her role, too, but besides these 2 women,
# be remade, stop it! The only thing this movie was good for was to show people that a remade 90's ver
# n give you three examples of remakes that were as good as the original: Cape Fear and the 1956 & 195
# tching the store when this was being made nothing good at all...Vince Vaughn couldn't make "Norman B
#  got my mom to rent it for me b/c she told me how good of a film it was. I remember watching 'Alfred
# lated more to their culture and I feel they did a good job at interpreting it to be made in the U.S.
# es and throwing in a Basic Instinct sex scene for good measure. Psycho is like Casablanca, Laura, It
# eally is lost. The acting and directing aren't as good. The movie is in color so it loses the same t
# s-- and his performance here is excellent; but as good as it is, the attitude and delivery are pure
#  through on his pointless conceit and squanders a good cast in the process. Though the 1998 version
# rly, utterly POINTLESS.Not terrible, not bad, not good - just.. pointless.  I have no real problem w
# seen Anne Heche in other movies and she is a very good actress, but she was not really allowed to ac
# glimpse or two of a cool butt, an absurd waste of good time.  Do not both watching it.
# istic and silly. Although Bret Easton Ellis did a good job in the novel Less Than Zero when painting
# , though I consider Christian Bale to be a really good actor, were I he, I would never have consente
# s are ambiguous because they  can't think of much good to say, but feel they have to.  The movie was
# s between a comedy and horror and failed at both. Good thing it was free with amazon prime, I'd have
# dangers of capitalism.  The soundtrack was pretty good, but the problem is the best songs are not on
# good show for kids for sure but very disturbing.
#  was terribly disappointed.  Christian Bale did a good job, but he was failed by the script and the
#  total STINK-O story.  Sandra as always puts in a good performance, but the characters and story are
# how this won all the awards. It starts out pretty good and ends pretty good. But the rest, no thank
# e version is a horrible transfer and the other is good, or a dvd set has packaging issues, it's all
# "high definition" on a computer would probably be good too, but there is no way to watch it unless e
# t in buying this Blu-Ray disc; the DVD is just as good or better.
# t part.3. It takes FOREVER to load. I'm talking a good 15-20 minutes from the time you put the disk
# akably awesome; YES, TERMINATOR 2 on Blu-ray is a good thing...BUT NOT THIS VERSION.For one, it's TH
# worst popular movie ever made and marketed in the good ole U.S. of A.(it's significantly worse than
# r this movie is Stone's sex scenes, says it all.  Good thing she is attractive, because she can't ac
# izard Of Oz. But we're not here to talk about the good stuff, remember (read my profile) - only the
# good as people make out - more surface than substa
# iolence while still having a point.There are some good things like the use of flashbacks and some go
# el SO MUCH like I've (still!) been sold a bill of goods. Tarantino has got NOTHING to "say" unless:
# good reason is sickening. I stopped watching when
# k. pulp fiction is alright, jackie brown isn't as good as rum punch the book, and kill bill was a wa
# er &quot;jackie brown&quot;, which was based on a good Elmore Leonard  novel. In &quot;Reservoir Dog
# who loved it, and if you enjoy the genre, it's as good as it gets. For my part, I wish I had never s
#  any of them get caught the rest of them are safe.Good so far?Now, QT likes to direct films based on
# an't imagine anyone coming away from this feeling good about it in any way shape or form.  And that
# ep thinking Quentin Tarantino will ever deliver a good movie.
# ck was that&#34; in many places. There's a lot of good elements for a genuinely good story here but
#  have come to grips with people giving bad movies good ratings. Caught Up is bad..really, really bad
# as it about America in the 1960's. The only thing good and authentic about this film is the music.
# ling department, where "Wishmaster" fails to make good use of the concept it so blatantly smothers.
#  own conclusions. (not really saying that one was good, no way)
# ws for "Jacob's Ladder", I thought I was in for a good scary movie and psychological thriller.  What
# ait for it to end.  Tin Robbins is usually pretty good, but even he seems bored to death in his role
# ing this is a form of psychedelic torture.Nothing good happens in this movie. You'll finish the movi
#  book, for fiery romance, erotic excitement and a good story.  While reading it play a CD with lovel
# to be annoying.  I liked Anna Paquin-she was very good, but one little girl doesn't a great movie ma
#   Holly Hunter (Ada, the mute love interest) is a good actress but most of the scenes were eyes dart
# f logic to this movie, unlike the first which was good. After this, is the most horrific movie seque
# A funny thing though is that the first RAMBO is a good movie. I love it. It is actually good, as har
# d.And, the scary thing is, well, look at all the "good" reviews on here. THAT'S scary!!! Why? You ma
# most every week it seemed, and although some were good - this is one you'll want to forget in a hurr
# eed any CGI or film-trick fanciness.It just needs good treatment.Though at the time as my writing th
# nal which goes to prove that that is not always a good thing to do. I was convinced that this was a
# 'll go reach for the original Diabolique for some good old fashioned husband-killing entertainment.
#  intricate and detailed, at least have a smashing good time giving us thrills, chills and gunfights.
# olence all of which is committed in the name of a good cause, although it is hard to see how the vio
# hat. Finally, who in the right mind said it was a good idea to involve Ally Walker into the mix? And
# ect them. They go home happy believing they did a good job. You, the consumer, you go and see it on

# %% [markdown]
# Vemos que "bueno" se usa de diferentes maneras en las críticas negativas. Por ejemplo:
#
# 1. A veces, el revisor señala algo que es realmente bueno, antes de decir que esto no compensa problemas más importantes.
# 2. A veces, el crítico dice que algo bueno no está presente, ya que "casi todo lo que he visto hasta ahora no se parece al buen cine de ninguna manera".
# 3. De vez en cuando, la palabra "bueno" se refiere a la moralidad.

# %% [markdown]
# Revise la lista de malas críticas que contienen la palabra "buena" que encontramos en la última pregunta. Para cada revisión, extraiga lo siguiente:
#
# 1. La primera palabra después de "good"
# 2. La primera palabra después de "good" que es un sustantivo o cardinal
# 3. La última palabra antes de "good" que es un sustantivo o cardinal

# %%
# PArte i
import re

post_good = []
for sentence in good_word_bad_review:

    # extraer la palabra seguida de good. Hacemos un strip de caracteres
    post = re.search("good.?\W*(\w+).*\s?", sentence, re.IGNORECASE)

    # si good es la ultima palabra en el review no habra palabra
    # despues de ella
    if post:
        post_good.append(post.groups()[0])

post_good = [i for i in post_good if i]
print(post_good[0:10])
# Out:
# ['the', 'but', 'for', 'plot', 'cinema', 'and', 'or', 'and', 'because', 'to']

# %%
# Parte ii
nltk.download('averaged_perceptron_tagger')
good_pos = ['CD', 'FW', 'NN', 'NNS', 'NNP', 'NNPS']

def extract_interesting(sentence, good):
    words = nltk.word_tokenize(sentence)
    interesting = [k for k, v in nltk.pos_tag(words) if v in good]
    return(interesting)

# Usamos esto para definir una nueva funcion para la proxima palabra interesante
def next_word2(sentence):
    post = re.findall(r'good.*', sentence)
    if len(post) > 0:
        interesting = extract_interesting(post[0], good_pos)
        if (len(interesting) > 0):
            return(interesting[0])
        else:
            return('')
    else:
        return('')

# Finalmente, buscamos en nuestra lista
post_good2 = []

for sentence in good_word_bad_review[:1000]:
    temp = next_word2(sentence)
    post_good2.append(temp)

post_good2 = [i for i in post_good2 if i]
print(post_good2[0:10])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ['story', 'scene', 'plot', 'cinema', 'history', 'benefit', 'scenes.To', 'filmmaker', 'extent', 'review']

# %%
# parte III
# funcion para extraer palabras antes  de que parezca la palabra "good"

def prev_word(sentence):
    post = re.findall(r'.*?good', sentence)
    if (len(post) > 0):
        temp = extract_interesting(post[0],good_pos)
        if (len(temp) > 0):
            return(temp[len(temp)-1])
        else:
            return('')
    else:
        return('')

# Encontramos nuestra lista
pre_good = []
for sentence in good_word_bad_review[:1000]:
    temp = prev_word(sentence)
    pre_good.append(temp)

pre_good = [i for i in pre_good if i]
print(pre_good[0:10])
# Out:
# ['acting', 'transfer', 'story', 'everything', 'acting', 'nothing', 'flashbacks', 'symbol', '.They', 'film']

# %% [markdown]
# # n-grams

# %% [markdown]
# Hemos visto que las palabras individuales no siempre son muy informativas. Busque los bigramas y trigramas más informativos, tanto en reseñas positivas como negativas. Muestre los bigramas y trigramas más informativos y haga un breve análisis de los n-gramas que identificó.

# %%
def get_top_n_words(corpus, n=1, k=1):
    vec = CountVectorizer(ngram_range=(k,k),stop_words = 'english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# Bigramas con buenas revisiones
common_words = get_top_n_words(good_reviews['reviewText'], 20, 2)
for word, freq in common_words:
    print(word, freq)

df = pd.DataFrame(common_words, columns=['words', 'count'])
df.groupby('words').sum()['count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 20 bigrams from good reviews'
)
# Out:
# blu ray 6714
# great movie 4300
# ve seen 3895
# special effects 3830
# good movie 2669
# love movie 2509
# sci fi 2246
# years ago 2191
# movie great 2152
# quot quot 1935
# black white 1927
# special features 1874
# watch movie 1853
# don know 1824
# highly recommend 1812
# year old 1799
# seen movie 1774
# new york 1720
# great film 1683
# real life 1471
# <AxesSubplot:title={'center':'Top 20 bigrams from good reviews'}, xlabel='words'>

# %%
# trigramas para buenas revisiones
common_words = get_top_n_words(good_reviews['reviewText'], 20, 3)
for word, freq in common_words:
    print(word, freq)

df = pd.DataFrame(common_words, columns=['words', 'count'])
df.groupby('words').sum()['count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 20 trigrams from good reviews'
)
# Out:
# tommy lee jones 779
# nightmare elm street 640
# does great job 467
# world war ii 456
# did great job 433
# new york city 427
# blu ray version 412
# ve seen movie 383
# highly recommend movie 350
# based true story 344
# blu ray release 316
# does good job 310
# did good job 283
# country old men 273
# special edition dvd 265
# movie ve seen 262
# dvd blu ray 251
# haven seen movie 250
# movies ve seen 247
# does excellent job 216
# <AxesSubplot:title={'center':'Top 20 trigrams from good reviews'}, xlabel='words'>

# %% [markdown]
# Algunos de los bigramas y trigramas están claramente relacionados con el tema, pero no necesariamente con buenas críticas. Por ejemplo, "blu ray", "lanzamiento de blu ray", "tommy lee jones", "historia real basada".
#
# Otros están más obviamente relacionados específicamente con buenas críticas, como "hace un trabajo excelente", "muy recomendable", "gran película".

# %% [markdown]
# Las palabras importantes como "bueno" (así como las que aparecen en los otros n-gramas anteriores) tienden a ser adjetivos. Los adjetivos describen sustantivos. Más específicamente, un adjetivo casi siempre describe el sustantivo que le sigue y que está más cerca de él en una oración. A veces los adjetivos no van directamente después. Por ejemplo, "Esta fue una película buena e interesante" todavía tiene "buena" y "película" vinculadas.
#
# Esto sugiere que podemos usar el etiquetado POS para extraer las ubicaciones de los adjetivos y sustantivos, luego iterar a través de todos los adjetivos y contar hacia adelante desde cada uno hasta llegar al siguiente sustantivo. Estas son nuestras palabras informativas.

# %% [markdown]
# Escribamos una(s) función(es) que transforme una oración en una nueva lista de texto emparejando iterativamente cada adjetivo en la oración con el siguiente sustantivo que le sigue en la oración. Por ejemplo, el texto "Esa fue una película larga y buena" debería devolver ["buena película", "película larga"].

# %%
#Hacemos una función que toma el primer adjetivo y su sustantivo asociado, luego devuelve (i) el par y (ii) una oración más corta.
def grab_first_pair(sentence):
    words = nltk.word_tokenize(sentence)
    adjectives = [k for k, v in nltk.pos_tag(words) if v == 'JJ']
    if(len(adjectives) > 0):
        shorter = re.findall(adjectives[0] +'.*',sentence)[0]
        words2 = nltk.word_tokenize(shorter)
        nouns = [k for k,v in nltk.pos_tag(words) if v == 'NN']
        if(len(nouns) > 0):
            shorter = shorter.split(' ', 1)[1]
            return(adjectives[0], nouns[0], shorter)
    return('', '', '')

# Creamos una funcion que use la anterior para iterar en las oraciones
def grab_all_pairs(sentence):
    pairs = []
    noun = ''
    adj =''
    while(len(sentence) > 0):
        adj, noun, sentence = grab_first_pair(sentence)
        if(adj != ''):
            pairs.append(adj + ' ' + noun)
    return(pairs)

#Creamos una funcion que itere por muchas oraciones luego de tokenizar
def make_pair_list(corpus):
    sentences = nltk.sent_tokenize(BigRev)
    pairs = []
    for sentence in sentences:
        pairs.extend(grab_all_pairs(sentence))

# %%
sentence = "The big black dog scared the red cat."
print(grab_first_pair(sentence))
print(grab_all_pairs(sentence))
# Out:
# ('big', 'dog', 'black dog scared the red cat.')
# ['big dog', 'black dog', 'red dog', 'red cat']
